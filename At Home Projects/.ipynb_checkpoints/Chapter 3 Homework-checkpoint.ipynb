# %%
professionals_dict = {
    "Gleeman, Aaron":{"Position/Area of Expertise":"Twins Beat Reporter",
                      "Biography":"Minnesota Twins reporter for The Athletic. Co-Host of Gleeman and the Geek. National Sports Media Association's 2021 Minnesota Sportswriter of the Year.",
                      "Twitter Handle":"@AaronGleeman"},
    "Frank, Jeremy":{"Position/Area of Expertise":"Baseball Analytics",
                      "Biography":"2022 Purdue Gradutate. Chicago Cubs Baseball Operations Associate. Co-Creator of mlbpickle.com",
                      "Twitter Handle":"@MLBRandomStats"},
    "Szymborski, Dan":{"Position/Area of Expertise":"Baseball Analytics",
                      "Biography":"Senior Writer for FanGraphs, ESPN contributor, data consultant, ZiPS Creator, BBWAA member",
                      "Twitter Handle":"@DSzymborski"},
    "Sarris, Eno":{"Position/Area of Expertise":"Baseball Analytics",
                      "Biography":"Writer at The Athletic, Creator of Stuff+, Rates and Barrels and 3-0 Show Pods Host",
                      "Twitter Handle":"@enosarris"},
    "Pollack, Nick":{"Position/Area of Expertise":"Baseball Writer and Analyst",
                      "Biography":"PitcherList.com founder. Player Pages + FSWA-winning articles & baseball podcasts.",
                      "Twitter Handle":"@Pitcherlist"},
    "Fast, Alex":{"Position/Area of Expertise":"Baseball Writer and Analyst/Graphics Creator",
                      "Biography":"VP of PitcherList. Overlay Creator for ESPN, MLB Network, and MASN. Tout Wars winner. Sports Emmys Recipient. FSWA Award Winner.",
                      "Twitter Handle":"@AlexFast8"},
    "Cross, Eric":{"Position/Area of Expertise":"Baseball Writer and Analyst",
                      "Biography":"2021 FSWA Baseball Writer of the Year. Lead MLB writer at Fantrax. Founder of The Toolshed Podcast",
                      "Twitter Handle":"@EricCross04"},
    "Clegg, Chris":{"Position/Area of Expertise":"Baseball Writer and Analyst",
                      "Biography":"Lead Dynasty Analyst at Pitcherlist. Founder of the Dynasty Dugout. Featured writer at FantasyPros",
                      "Twitter Handle":"@RotoClegg"},
    "Williams, Matt":{"Position/Area of Expertise":"Baseball Writer and Analyst",
                      "Biography":"Lead MLB Editor at The Gameday HQ. FSWA Award Nominee. Tout Wars Champ",
                      "Twitter Handle":"@MattWi77iams"},
    "Bonnes, John":{"Position/Area of Expertise":"Twins Beat Writer",
                      "Biography":"Founder of Twins Daily. Gleeman and the Geek Co-Host. Twins Radio Personality",
                      "Twitter Handle":"@TwinsGeek"}}

professionals_dict
# Out:
# {'Gleeman, Aaron': {'Position/Area of Expertise': 'Twins Beat Reporter',
#   'Biography': "Minnesota Twins reporter for The Athletic. Co-Host of Gleeman and the Geek. National Sports Media Association's 2021 Minnesota Sportswriter of the Year.",
#   'Twitter Handle': '@AaronGleeman'},
#  'Frank, Jeremy': {'Position/Area of Expertise': 'Baseball Analytics',
#   'Biography': '2022 Purdue Gradutate. Chicago Cubs Baseball Operations Associate. Co-Creator of mlbpickle.com',
#   'Twitter Handle': '@MLBRandomStats'},
#  'Szymborski, Dan': {'Position/Area of Expertise': 'Baseball Analytics',
#   'Biography': 'Senior Writer for FanGraphs, ESPN contributor, data consultant, ZiPS Creator, BBWAA member',
#   'Twitter Handle': '@DSzymborski'},
#  'Sarris, Eno': {'Position/Area of Expertise': 'Baseball Analytics',
#   'Biography': 'Writer at The Athletic, Creator of Stuff+, Rates and Barrels and 3-0 Show Pods Host',
#   'Twitter Handle': '@enosarris'},
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(professionals_dict)
# Out:
#                                                                Gleeman, Aaron  \
# Position/Area of Expertise                                Twins Beat Reporter
# Biography                   Minnesota Twins reporter for The Athletic. Co-...
# Twitter Handle                                                  @AaronGleeman
#
#                                                                 Frank, Jeremy  \
# Position/Area of Expertise                                 Baseball Analytics
# Biography                   2022 Purdue Gradutate. Chicago Cubs Baseball O...
# Twitter Handle                                                @MLBRandomStats
#
#                                                               Szymborski, Dan  \
# Position/Area of Expertise                                 Baseball Analytics
# Biography                   Senior Writer for FanGraphs, ESPN contributor,...
# Twitter Handle                                                   @DSzymborski
#
# ...

# %%
pd.DataFrame(professionals_dict).T
# Out:
#                                    Position/Area of Expertise  \
# Gleeman, Aaron                            Twins Beat Reporter
# Frank, Jeremy                              Baseball Analytics
# Szymborski, Dan                            Baseball Analytics
# Sarris, Eno                                Baseball Analytics
# Pollack, Nick                     Baseball Writer and Analyst
# Fast, Alex       Baseball Writer and Analyst/Graphics Creator
# Cross, Eric                       Baseball Writer and Analyst
# Clegg, Chris                      Baseball Writer and Analyst
# Williams, Matt                    Baseball Writer and Analyst
# Bonnes, John                                Twins Beat Writer
#
#                                                          Biography  \
# Gleeman, Aaron   Minnesota Twins reporter for The Athletic. Co-...
# Frank, Jeremy    2022 Purdue Gradutate. Chicago Cubs Baseball O...
# Szymborski, Dan  Senior Writer for FanGraphs, ESPN contributor,...
# ...

# %%
pro_df = pd.DataFrame(professionals_dict).T
pro_df.to_csv("ProDF.csv")
