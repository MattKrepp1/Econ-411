# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

oecd_countries = ["Australia", "Austria", "Belgium", "Canada", "Chile", "Colombia", "Costa Rica",
            "Czech Republic", "Denmark", "Estonia", "Finland", "France", "Germany",
            "Greece", "Hungary", "Iceland", "Ireland", "Israel", "Italy", "Japan", 
            "Latvia", "Lithuania","Luxembourg", "Mexico", "Netherlands", "New Zealand", "Norway",
             "Poland","Portugal", "Slovakia", "Slovenia", "South Korea", "Spain", "Sweden",
             "Switzerland", "Turkey", "United Kingdom", "United States"]

hw_data = pd.read_excel("Copy of EFWAndRGDP.xls")
hw_data[hw_data["Countries"].isin(oecd_countries)]
# Out:
#      ISO_Code_3  Year ISO_Code_2    World Bank Region  \
# 135         AUS  1970         AU  East Asia & Pacific
# 136         NaN  1975         AU  East Asia & Pacific
# 137         NaN  1980         AU  East Asia & Pacific
# 138         NaN  1985         AU  East Asia & Pacific
# 139         NaN  1990         AU  East Asia & Pacific
# ...         ...   ...        ...                  ...
# 4288        NaN  2016         US        North America
# 4289        NaN  2017         US        North America
# 4290        NaN  2018         US        North America
# 4291        NaN  2019         US        North America
# 4292        NaN  2020         US        North America
#
#      World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# 135                                                 NaN
# 136                                                 NaN
# 137                                                 NaN
# 138                                                 NaN
# 139                                                   H
# ...                                                 ...
# 4288                                                  H
# 4289                                                  H
# 4290                                                  H
# 4291                                                  H
# 4292                                                  H
#
#           Countries   Summary  Size of Government  \
# 135       Australia  7.291154            6.863768
# 136       Australia  7.002204            6.255684
# 137       Australia  7.316469            6.339449
# 138       Australia  7.670016            6.259326
# 139       Australia  7.927001            6.708215
# ...             ...       ...                 ...
# 4288  United States  8.339536            7.252009
# 4289  United States  8.379486            7.354358
# 4290  United States  8.279612            7.409095
# 4291  United States  8.249649            7.320058
# 4292  United States  7.970000            6.790621
#
#       Legal System and Property Rights  Sound Money  \
# 135                           7.775615     9.581113
# 136                           8.034445     8.346907
# 137                           8.037057     9.085686
# 138                           8.540345     9.089736
# 139                           8.398730     9.018318
# ...                                ...          ...
# 4288                          7.793107     9.814703
# 4289                          7.802657     9.772320
# 4290                          7.646530     9.772494
# 4291                          7.644319     9.747903
# 4292                          7.555009     9.626843
#
#       Freedom to Trade Internationally  Regulation  \
# 135                           5.882101    6.335298
# 136                           5.692162    6.761980
# 137                           5.841104    7.389934
# 138                           6.985368    7.469774
# 139                           7.661409    7.750886
# ...                                ...         ...
# 4288                          7.889129    8.952382
# 4289                          7.921225    9.031901
# 4290                          7.783384    8.784245
# 4291                          7.829949    8.682216
# 4292                          7.765508    8.109914
#
#       Standard Deviation of the 5 EFW Areas  RGDP Per Capita
# 135                                1.462900       19166.0000
# 136                                1.140578       20993.0000
# 137                                1.302266       22972.0000
# 138                                1.148037       24927.0000
# 139                                0.865823       27373.0000
# ...                                     ...              ...
# 4288                               1.029060       53015.0000
# 4289                               0.994888       54007.7698
# 4290                               0.985924       55334.7394
# 4291                               0.979602              NaN
# 4292                               1.045188              NaN
#
# [972 rows x 14 columns]

# %%
iso = pd.read_excel("ISO3.xls")
iso
# Out:
#      ISO_Code_3  Year ISO_Code_2              World Bank Region  \
# 0           ALB  2020         AL          Europe & Central Asia
# 1           DZA  2020         DZ     Middle East & North Africa
# 2           AGO  2020         AO             Sub-Saharan Africa
# 3           ARG  2020         AR  Latin America & the Caribbean
# 4           ARM  2020         AM          Europe & Central Asia
# ...         ...   ...        ...                            ...
# 4450        VEN  1970         VE  Latin America & the Caribbean
# 4451        VNM  1970         VN            East Asia & Pacific
# 4452        YEM  1970         YE     Middle East & North Africa
# 4453        ZMB  1970         ZM             Sub-Saharan Africa
# 4454        ZWE  1970         ZW             Sub-Saharan Africa
#
#      World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# 0                                                    UM
# 1                                                    LM
# 2                                                    LM
# 3                                                    UM
# 4                                                    UM
# ...                                                 ...
# 4450                                                NaN
# 4451                                                NaN
# 4452                                                NaN
# 4453                                                NaN
# 4454                                                NaN
#
#           Countries   Summary  Size of Government  \
# 0           Albania  7.640000            7.817077
# 1           Algeria  5.120000            4.409943
# 2            Angola  5.910000            8.133385
# 3         Argentina  4.870000            6.483768
# 4           Armenia  7.840000            7.975292
# ...             ...       ...                 ...
# 4450  Venezuela, RB  7.242943            8.349529
# 4451        Vietnam       NaN                 NaN
# 4452    Yemen, Rep.       NaN                 NaN
# 4453         Zambia  4.498763            5.374545
# 4454       Zimbabwe       NaN                 NaN
#
#       Legal System and Property Rights  Sound Money  \
# 0                             5.260351     9.788269
# 1                             4.131760     7.630287
# 2                             3.705161     6.087996
# 3                             4.796454     4.516018
# 4                             6.236215     9.553009
# ...                                ...          ...
# 4450                          5.003088     9.621851
# 4451                               NaN          NaN
# 4452                               NaN          NaN
# 4453                          4.472812     5.137395
# 4454                               NaN          NaN
#
#       Freedom to Trade Internationally  Regulation  RGDP Per Capita
# 0                             8.222499    7.112958              NaN
# 1                             3.639507    5.778953              NaN
# 2                             5.373190    6.227545              NaN
# 3                             3.086907    5.490538              NaN
# 4                             7.692708    7.756333              NaN
# ...                                ...         ...              ...
# 4450                          7.895993    5.209592          15289.0
# 4451                               NaN         NaN           1172.0
# 4452                               NaN         NaN           1961.0
# 4453                               NaN    5.307952           1710.0
# 4454                               NaN         NaN           2043.0
#
# [4455 rows x 13 columns]

# %%
del iso["Year"]
del iso["ISO_Code_2"]
del iso["World Bank Region"]
del iso["World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)"]
del iso["Summary"]
del iso["Size of Government"]
del iso["Legal System and Property Rights"]
del iso["Sound Money"]
del iso["Freedom to Trade Internationally"]
del iso["Regulation"]
del iso["RGDP Per Capita"]
iso
# Out:
#      ISO_Code_3      Countries
# 0           ALB        Albania
# 1           DZA        Algeria
# 2           AGO         Angola
# 3           ARG      Argentina
# 4           ARM        Armenia
# ...         ...            ...
# 4450        VEN  Venezuela, RB
# 4451        VNM        Vietnam
# 4452        YEM    Yemen, Rep.
# 4453        ZMB         Zambia
# 4454        ZWE       Zimbabwe
#
# [4455 rows x 2 columns]

# %%
iso = iso[iso["Countries"].isin(oecd_countries)]
iso
# Out:
#      ISO_Code_3       Countries
# 5           AUS       Australia
# 6           AUT         Austria
# 13          BEL         Belgium
# 28          CAN          Canada
# 31          CHL           Chile
# ...         ...             ...
# 4432        SWE          Sweden
# 4433        CHE     Switzerland
# 4443        TUR          Turkey
# 4447        GBR  United Kingdom
# 4448        USA   United States
#
# [972 rows x 2 columns]

# %%
iso = iso.drop_duplicates()
iso
# Out:
#     ISO_Code_3       Countries
# 5          AUS       Australia
# 6          AUT         Austria
# 13         BEL         Belgium
# 28         CAN          Canada
# 31         CHL           Chile
# 33         COL        Colombia
# 37         CRI      Costa Rica
# 41         CZE  Czech Republic
# 42         DNK         Denmark
# 48         EST         Estonia
# 52         FIN         Finland
# 53         FRA          France
# 57         DEU         Germany
# 59         GRC          Greece
# 67         HUN         Hungary
# 68         ISL         Iceland
# 73         IRL         Ireland
# 74         ISR          Israel
# 75         ITA           Italy
# 77         JPN           Japan
# 85         LVA          Latvia
# 90         LTU       Lithuania
# 91         LUX      Luxembourg
# 99         MEX          Mexico
# 108        NLD     Netherlands
# 109        NZL     New Zealand
# 114        NOR          Norway
# 122        POL          Poland
# 123        PRT        Portugal
# 135        SVN        Slovenia
# 138        ESP           Spain
# 142        SWE          Sweden
# 143        CHE     Switzerland
# 153        TUR          Turkey
# 157        GBR  United Kingdom
# 158        USA   United States

# %%
result = pd.merge(hw_data, iso, on="Countries")
result
# Out:
#     ISO_Code_3_x  Year ISO_Code_2    World Bank Region  \
# 0            AUS  1970         AU  East Asia & Pacific
# 1            NaN  1975         AU  East Asia & Pacific
# 2            NaN  1980         AU  East Asia & Pacific
# 3            NaN  1985         AU  East Asia & Pacific
# 4            NaN  1990         AU  East Asia & Pacific
# ..           ...   ...        ...                  ...
# 967          NaN  2016         US        North America
# 968          NaN  2017         US        North America
# 969          NaN  2018         US        North America
# 970          NaN  2019         US        North America
# 971          NaN  2020         US        North America
#
#     World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                    H
# ..                                                 ...
# 967                                                  H
# 968                                                  H
# 969                                                  H
# 970                                                  H
# 971                                                  H
#
#          Countries   Summary  Size of Government  \
# 0        Australia  7.291154            6.863768
# 1        Australia  7.002204            6.255684
# 2        Australia  7.316469            6.339449
# 3        Australia  7.670016            6.259326
# 4        Australia  7.927001            6.708215
# ..             ...       ...                 ...
# 967  United States  8.339536            7.252009
# 968  United States  8.379486            7.354358
# 969  United States  8.279612            7.409095
# 970  United States  8.249649            7.320058
# 971  United States  7.970000            6.790621
#
#      Legal System and Property Rights  Sound Money  \
# 0                            7.775615     9.581113
# 1                            8.034445     8.346907
# 2                            8.037057     9.085686
# 3                            8.540345     9.089736
# 4                            8.398730     9.018318
# ..                                ...          ...
# 967                          7.793107     9.814703
# 968                          7.802657     9.772320
# 969                          7.646530     9.772494
# 970                          7.644319     9.747903
# 971                          7.555009     9.626843
#
#      Freedom to Trade Internationally  Regulation  \
# 0                            5.882101    6.335298
# 1                            5.692162    6.761980
# 2                            5.841104    7.389934
# 3                            6.985368    7.469774
# 4                            7.661409    7.750886
# ..                                ...         ...
# 967                          7.889129    8.952382
# 968                          7.921225    9.031901
# 969                          7.783384    8.784245
# 970                          7.829949    8.682216
# 971                          7.765508    8.109914
#
#      Standard Deviation of the 5 EFW Areas  RGDP Per Capita ISO_Code_3_y
# 0                                 1.462900       19166.0000          AUS
# 1                                 1.140578       20993.0000          AUS
# 2                                 1.302266       22972.0000          AUS
# 3                                 1.148037       24927.0000          AUS
# 4                                 0.865823       27373.0000          AUS
# ..                                     ...              ...          ...
# 967                               1.029060       53015.0000          USA
# 968                               0.994888       54007.7698          USA
# 969                               0.985924       55334.7394          USA
# 970                               0.979602              NaN          USA
# 971                               1.045188              NaN          USA
#
# [972 rows x 15 columns]

# %%
del result["ISO_Code_3_x"]
del result["World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)"]

# %%
result = result.dropna()

# %%
years_diff = 5
x_vars = result[['Size of Government', 'Legal System and Property Rights', 'Sound Money', 'Freedom to Trade Internationally', 'Regulation']]
y_var = result[['RGDP Per Capita']]

# %%
r_df = result.dropna(axis = 0, how = "any")
y = y_var
x = x_vars
x["Constant"] = 1
results = sm.OLS(y, x).fit()
r_df["Prediction"] = results.predict()
r_df["Residuals"] = results.resid
results.summary()
# Out:
# /var/folders/hz/vggy99z9791d4jlzyvlw3r9w0000gn/T/ipykernel_15241/2719920473.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Constant"] = 1
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        RGDP Per Capita   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.562
# Method:                 Least Squares   F-statistic:                     224.0
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):          3.60e-153
# Time:                        16:05:49   Log-Likelihood:                -9174.3
# No. Observations:                 869   AIC:                         1.836e+04
# Df Residuals:                     863   BIC:                         1.839e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Size of Government                -820.3802    350.222     -2.342      0.019   -1507.767    -132.994
# Legal System and Property Rights  6102.0250    367.185     16.618      0.000    5381.345    6822.705
# Sound Money                       2250.7536    312.911      7.193      0.000    1636.598    2864.909
# Freedom to Trade Internationally  -792.1670    371.394     -2.133      0.033   -1521.109     -63.225
# Regulation                        2298.3939    467.796      4.913      0.000    1380.243    3216.545
# Constant                         -3.934e+04   3385.581    -11.619      0.000    -4.6e+04   -3.27e+04
# ==============================================================================
# Omnibus:                      205.420   Durbin-Watson:                   0.234
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              585.081
# Skew:                           1.178   Prob(JB):                    8.94e-128
# Kurtosis:                       6.257   Cond. No.                         182.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
result["Residuals"] = results.resid
fig, ax = plt.subplots(figsize = (12,8))
result[["Residuals"]].plot.hist(bins = 100, ax = ax)
# Out:
# /var/folders/hz/vggy99z9791d4jlzyvlw3r9w0000gn/T/ipykernel_15241/1237131590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result["Residuals"] = results.resid
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# This histogram is different from the others because it shows that the residuals don't follow a normal distribution.

# %%
results_dict = {"Beta":results.params,
               "t-stats": results.tvalues,
               "p-values":results.pvalues,
               "SE":results.bse}
results_df = pd.DataFrame(results_dict).round(3)
results_df.to_csv("y = RGPDPC, X = EFW, LogDiffResults.csv")
results_df
# Out:
#                                        Beta  t-stats  p-values        SE
# Size of Government                 -820.380   -2.342     0.019   350.222
# Legal System and Property Rights   6102.025   16.618     0.000   367.185
# Sound Money                        2250.754    7.193     0.000   312.911
# Freedom to Trade Internationally   -792.167   -2.133     0.033   371.394
# Regulation                         2298.394    4.913     0.000   467.796
# Constant                         -39337.402  -11.619     0.000  3385.581

# %%
result.plot.scatter(x = x_vars[0],
                     y = "Predictor", 
                      s = 30, ax = ax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/hz/vggy99z9791d4jlzyvlw3r9w0000gn/T/ipykernel_15241/2292249265.py in <module>
# ----> 1 result.plot.scatter(x = x_vars[0],
#       2                      y = "Predictor",
#       3                       s = 30, ax = ax)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
def plot_residuals(result, y_var, x_vars):
    fig, ax = plt.subplots(figsize = (14, 10))
    result.plot.scatter(x = result["RDPG Per Capita"],
                     y = "Prediction", 
                      s = 30, ax = ax)
    plt.xticks(rotation=90)
    plt.show()
    plt.close()

    # cycle through all variables included in regression
    #   concatenate y_var and x_vars to form a single list
    for var in y_var + x_vars:
        fig, ax = plt.subplots(figsize = (14,10))
        result.plot.scatter(x = var,
                         y = "Residuals", 
                          s = 30, ax = ax)
        ax.axhline(0, ls = "--", color = "k")
        plt.xticks(rotation=90)
        plt.show()
        plt.close()
        
plot_residuals(result, result["RGDP Per Capita"], x_vars)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RDPG Per Capita'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/hz/vggy99z9791d4jlzyvlw3r9w0000gn/T/ipykernel_15241/2265044317.py in <module>
#      20         plt.close()
#      21
# ---> 22 plot_residuals(result, result["RGDP Per Capita"], x_vars)
#
# /var/folders/hz/vggy99z9791d4jlzyvlw3r9w0000gn/T/ipykernel_15241/2265044317.py in plot_residuals(result, y_var, x_vars)
#       1 def plot_residuals(result, y_var, x_vars):
#       2     fig, ax = plt.subplots(figsize = (14, 10))
# ----> 3     result.plot.scatter(x = result["RDPG Per Capita"],
#       4                      y = "Prediction",
#       5                       s = 30, ax = ax)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'RDPG Per Capita'
